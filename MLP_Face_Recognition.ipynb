# %%
import matplotlib.pyplot as plt
import zipfile
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
import numpy as np
import os,cv2

def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h,w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

# %%
zip_ref = zipfile.ZipFile('dataset.zip')
zip_ref.extractall()
zip_ref.close()

# %%
for dirpath, dirnames, filenames in os.walk('dataset'):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")
# Out:
# There are 2 directories and 0 images in dataset
# There are 9 directories and 0 images in dataset\faces
# There are 0 directories and 50 images in dataset\faces\Aamir
# There are 0 directories and 50 images in dataset\faces\Ajay
# There are 0 directories and 50 images in dataset\faces\Akshay
# There are 0 directories and 50 images in dataset\faces\Alia
# There are 0 directories and 50 images in dataset\faces\Amitabh
# There are 0 directories and 50 images in dataset\faces\Deepika
# There are 0 directories and 50 images in dataset\faces\Disha
# There are 0 directories and 50 images in dataset\faces\Farhan
# There are 0 directories and 50 images in dataset\faces\Ileana
# There are 0 directories and 2 images in dataset\Iris

# %%
dir_name="dataset/faces/"
y=[];x=[];target_names=[]
person_id=0;h=w=300
n_samples=0
class_names=[]
for person_name in os.listdir(dir_name):
    dir_path = dir_name+person_name+"/"
    class_names.append(person_name)
    for image_name in os.listdir(dir_path):
        image_path = dir_path+image_name
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        resized_image= cv2.resize(gray,(h,w))
        v = resized_image.flatten()
        x.append(v)
        n_samples =n_samples+1
        y.append(person_id)
        target_names.append(person_name)
    person_id=person_id+1
y=np.array(y)
x=np.array(x)
target_names =np.array(target_names)
n_features = x.shape[1]
print(y.shape,x.shape,target_names.shape)
print("Number of samples:",n_samples)

n_classes = target_names.shape[0]

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# (450,) (450, 90000) (450,)
# Number of samples: 450
# Total dataset size:
# n_samples: 450
# n_features: 90000
# n_classes: 450

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

n_components = 150

print("Extracting the top %d eigenfaces from %d faces"% (n_components, x_train.shape[0]))

pca = PCA(n_components=n_components, svd_solver='randomized', whiten=True).fit(x_train)

eigenfaces = pca.components_.reshape((n_components, h, w))

eigenfaces_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenfaces_titles, h, w)

plt.show()

print("Projecting the input data on the eigenfaces orthonormal basis")
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)
print(x_train_pca.shape,x_test_pca.shape)

lda = LinearDiscriminantAnalysis()
lda.fit(x_train_pca, y_train)

x_train_lda = lda.transform(x_train_pca)
x_test_lda = lda.transform(x_test_pca)
print("Project done...")
# Out:
# Extracting the top 150 eigenfaces from 337 faces
# Projecting the input data on the eigenfaces orthonormal basis
# (337, 150) (113, 150)
# Project done...

# %%
clf = MLPClassifier(random_state=1, hidden_layer_sizes=(10,10), max_iter=1000, verbose=True).fit(x_train_lda, y_train)
print("Model weights:")
model_info = [coef.shape for coef in clf.coefs_]
print(model_info)
# Out:
# Iteration 1, loss = 2.93163762
# Iteration 2, loss = 2.88601611
# Iteration 3, loss = 2.84116501
# Iteration 4, loss = 2.79798652
# Iteration 5, loss = 2.75520407
# Iteration 6, loss = 2.71446866
# Iteration 7, loss = 2.67261511
# Iteration 8, loss = 2.63249099
# Iteration 9, loss = 2.59362034
# Iteration 10, loss = 2.55457807
# Iteration 11, loss = 2.51653303
# Iteration 12, loss = 2.48007094
# Iteration 13, loss = 2.44412908
# Iteration 14, loss = 2.40919176
# Iteration 15, loss = 2.37324483
# Iteration 16, loss = 2.33938406
# Iteration 17, loss = 2.30538714
# Iteration 18, loss = 2.27262126
# Iteration 19, loss = 2.24016720
# Iteration 20, loss = 2.20765827
# Iteration 21, loss = 2.17664871
# Iteration 22, loss = 2.14508885
# Iteration 23, loss = 2.11480396
# Iteration 24, loss = 2.08448420
# Iteration 25, loss = 2.05375415
# Iteration 614, loss = 0.02986600
# Iteration 615, loss = 0.02976299
# Iteration 616, loss = 0.02965012
# Iteration 617, loss = 0.02954156
# Iteration 618, loss = 0.02942750
# Iteration 619, loss = 0.02930972
# Iteration 620, loss = 0.02921065
# Iteration 621, loss = 0.02909446
# Iteration 622, loss = 0.02899288
# Iteration 623, loss = 0.02889790
# Iteration 624, loss = 0.02878079
# Iteration 625, loss = 0.02866809
# Iteration 626, loss = 0.02855979
# Iteration 627, loss = 0.02847645
# Iteration 628, loss = 0.02839398
# Iteration 629, loss = 0.02826726
# Iteration 630, loss = 0.02816922
# Iteration 631, loss = 0.02805317
# Iteration 632, loss = 0.02794023
# Iteration 633, loss = 0.02785021
# Iteration 634, loss = 0.02775300
# Iteration 635, loss = 0.02764882
# Iteration 636, loss = 0.02754494
# Iteration 637, loss = 0.02747334
# Iteration 638, loss = 0.02732674
# Iteration 639, loss = 0.02724474
# Iteration 640, loss = 0.02714582
# Iteration 641, loss = 0.02705118
# Iteration 642, loss = 0.02694536
# Iteration 643, loss = 0.02684682
# Iteration 644, loss = 0.02673813
# Iteration 645, loss = 0.02665220
# Iteration 646, loss = 0.02654303
# Iteration 647, loss = 0.02645549
# Iteration 648, loss = 0.02636077
# Iteration 649, loss = 0.02625900
# Iteration 650, loss = 0.02617654
# Iteration 651, loss = 0.02606439
# Iteration 652, loss = 0.02596646
# Iteration 653, loss = 0.02586860
# Iteration 654, loss = 0.02578993
# Iteration 655, loss = 0.02568576
# Iteration 656, loss = 0.02560446
# Iteration 657, loss = 0.02551764
# Iteration 658, loss = 0.02544375
# Iteration 659, loss = 0.02535342
# Iteration 660, loss = 0.02526006
# Iteration 661, loss = 0.02515214
# Iteration 662, loss = 0.02507129
# Iteration 663, loss = 0.02498864
# Iteration 664, loss = 0.02489682
# Iteration 665, loss = 0.02481429
# Iteration 666, loss = 0.02473150
# Iteration 667, loss = 0.02463398
# Iteration 668, loss = 0.02455449
# Iteration 669, loss = 0.02445207
# Iteration 670, loss = 0.02437566
# Iteration 671, loss = 0.02428125
# Iteration 672, loss = 0.02421085
# Iteration 673, loss = 0.02413346
# Iteration 674, loss = 0.02405285
# Iteration 675, loss = 0.02395179
# Iteration 676, loss = 0.02386622
# Iteration 677, loss = 0.02378663
# Iteration 678, loss = 0.02369546
# Iteration 679, loss = 0.02362542
# Iteration 680, loss = 0.02354930
# Iteration 681, loss = 0.02346707
# Iteration 682, loss = 0.02339086
# Iteration 683, loss = 0.02331002
# Iteration 684, loss = 0.02322470
# Iteration 685, loss = 0.02312559
# Iteration 686, loss = 0.02305268
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Model weights:
# [(8, 10), (10, 10), (10, 9)]

# %%
y_pred=[];y_prob=[]
for test_face in x_test_lda:
    prob = clf.predict_proba([test_face])[0]
    class_id = np.where(prob == np.max(prob))[0][0]
    y_pred.append(class_id)
    y_prob.append(np.max(prob))
    
y_pred = np.array(y_pred)

prediction_titles=[]
true_positive = 0
for i in range(y_pred.shape[0]):
    true_name = class_names[y_test[i]]
    pred_name = class_names[y_pred[i]]
    result = 'pred: %s, pr: %s \ntrue: %s' % (pred_name, str(y_prob[i])[0:3], true_name)
    prediction_titles.append(result)
    if true_name==pred_name:
       true_positive =true_positive+1
    
print("Accuracy",true_positive*100/y_pred.shape[0])

plot_gallery(x_test, prediction_titles, h, w)
plt.show()
# Out:
# Accuracy 72.56637168141593
